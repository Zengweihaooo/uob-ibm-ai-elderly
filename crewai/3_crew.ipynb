# %%
from dotenv import load_dotenv
load_dotenv()

from crewai import LLM

llm = LLM(
    model="gemini/gemini-2.0-flash",
    temperature=0.1
)

# %%
from crewai import Agent, Task, Crew

research_agent = Agent(
    role="Research Specialist",
    goal="Research interesting facts about the topic: {topic}",
    backstory="You are an expert at finding relevant and factual data",
    verbose=True,
    llm=llm
)

writer_agent= Agent(
    role="Creative Writer",
    goal="Write a short blog summary using the research",
    backstory="You are skilled at writing engaging summaries based on provided content.",
    verbose=True,
    llm=llm


)

# %%
task1 = Task(
    description="Find 3-5 interesting and recent facts about {topic}.",
    expected_output="A bullet list of 3-5 facts",
    agent=research_agent,
)

task2 = Task(
    description="Write a 100-word blog post summary about {topic} using the facts from the research.",
    expected_output="A blog post summary",agent=writer_agent,
    context=[task1],

)

crew = Crew(
    agents=[research_agent, writer_agent],
    tasks=[task1, task2],
    verbose=True,
)

crew.kickoff(inputs={"topic": "The Future of AI Voice Assistants for the Elderly"})
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 34bf416d-e0d9-40a8-aaba-367629043172                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Research Specialist                                                                                     │
# │                                                                                                                 │
# │  Task: Find 3-5 interesting and recent facts about The Future of AI Voice Assistants for the Elderly.           │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Research Specialist                                                                                     │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Here are 5 interesting and recent facts about the future of AI Voice Assistants for the Elderly:               │
# │                                                                                                                 │
# │  *   **AI Voice Assistants Can Improve Medication Adherence:** Studies have shown that AI voice assistants can  │
# │  significantly improve medication adherence among the elderly by providing reminders, information about         │
# │  medications, and even connecting them with pharmacists or healthcare providers. This is particularly           │
# │  important for seniors managing multiple prescriptions.                                                         │
# │                                                                                                                 │
# │  *   **AI Voice Assistants Can Help Reduce Social Isolation:** Loneliness and social isolation are major        │
# │  concerns for older adults. AI voice assistants can provide companionship, facilitate communication with        │
# │  family and friends, and offer access to social activities and support groups, helping to combat these issues.  │
# │                                                                                                                 │
# │  *   **AI Voice Assistants are Becoming More Proactive in Detecting Health Issues:** Future AI voice            │
# │  assistants are expected to go beyond simple commands and proactively monitor seniors' health. By analyzing     │
# │  voice patterns, sleep habits, and activity levels, they can detect early signs of health problems like         │
# │  cognitive decline, depression, or respiratory issues, and alert caregivers or medical professionals.           │
# │                                                                                                                 │
# │  *   **AI Voice Assistants are Integrating with Smart Home Technology for Enhanced Safety:** The integration    │
# │  of AI voice assistants with smart home devices is creating safer living environments for the elderly. They     │
# │  can control lighting, temperature, and appliances, as well as detect falls, gas leaks, or other emergencies,   │
# │  and automatically call for help.                                                                               │
# │                                                                                                                 │
# │  *   **AI Voice Assistants are Addressing Accessibility and Usability Challenges:** Developers are actively     │
# │  working on making AI voice assistants more accessible and user-friendly for older adults with varying levels   │
# │  of technical skills. This includes simplifying voice commands, providing visual aids, and offering             │
# │  personalized support to ensure that seniors can easily adopt and benefit from this technology.                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: bb206a64-7914-42c5-9ac6-012f8b92d89a                                                                     │
# │  Agent: Research Specialist                                                                                     │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Creative Writer                                                                                         │
# │                                                                                                                 │
# │  Task: Write a 100-word blog post summary about The Future of AI Voice Assistants for the Elderly using the     │
# │  facts from the research.                                                                                       │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Creative Writer                                                                                         │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  **The Future is Now: How AI Voice Assistants are Revolutionizing Elderly Care**                                │
# │                                                                                                                 │
# │  AI voice assistants are poised to transform elderly care, offering solutions to critical challenges faced by   │
# │  seniors. Studies show they boost medication adherence through reminders and easy access to healthcare          │
# │  information. Crucially, they combat social isolation by facilitating communication and providing               │
# │  companionship.                                                                                                 │
# │                                                                                                                 │
# │  Looking ahead, AI will proactively detect health issues by analyzing voice and activity patterns, enabling     │
# │  early intervention. Integration with smart home technology enhances safety, controlling environments and       │
# │  automatically calling for help in emergencies. Developers are also prioritizing accessibility, ensuring        │
# │  user-friendly designs for seniors of all tech skill levels. The future of aging is looking brighter, thanks    │
# │  to AI.                                                                                                         │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 41515899-c5dd-4e1f-acb2-f269d543f799                                                                     │
# │  Agent: Creative Writer                                                                                         │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: 34bf416d-e0d9-40a8-aaba-367629043172                                                                       │
# │  Tool Args:                                                                                                     │
# │  Final Output: **The Future is Now: How AI Voice Assistants are Revolutionizing Elderly Care**                  │
# │                                                                                                                 │
# │  AI voice assistants are poised to transform elderly care, offering solutions to critical challenges faced by   │
# │  seniors. Studies show they boost medication adherence through reminders and easy access to healthcare          │
# │  information. Crucially, they combat social isolation by facilitating communication and providing               │
# │  companionship.                                                                                                 │
# │                                                                                                                 │
# │  Looking ahead, AI will proactively detect health issues by analyzing voice and activity patterns, enabling     │
# │  early intervention. Integration with smart home technology enhances safety, controlling environments and       │
# │  automatically calling for help in emergencies. Developers are also prioritizing accessibility, ensuring        │
# │  user-friendly designs for seniors of all tech skill levels. The future of aging is looking brighter, thanks    │
# │  to AI.                                                                                                         │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# CrewOutput(raw='**The Future is Now: How AI Voice Assistants are Revolutionizing Elderly Care**\n\nAI voice assistants are poised to transform elderly care, offering solutions to critical challenges faced by seniors. Studies show they boost medication adherence through reminders and easy access to healthcare information. Crucially, they combat social isolation by facilitating communication and providing companionship.\n\nLooking ahead, AI will proactively detect health issues by analyzing voice and activity patterns, enabling early intervention. Integration with smart home technology enhances safety, controlling environments and automatically calling for help in emergencies. Developers are also prioritizing accessibility, ensuring user-friendly designs for seniors of all tech skill levels. The future of aging is looking brighter, thanks to AI.', pydantic=None, json_dict=None, tasks_output=[TaskOutput(description='Find 3-5 interesting and recent facts about The Future of AI Voice Assistants for the Elderly.', name=None, expected_output='A bullet list of 3-5 facts', summary='Find 3-5 interesting and recent facts about The Future of...', raw="Here are 5 interesting and recent facts about the future of AI Voice Assistants for the Elderly:\n\n*   **AI Voice Assistants Can Improve Medication Adherence:** Studies have shown that AI voice assistants can significantly improve medication adherence among the elderly by providing reminders, information about medications, and even connecting them with pharmacists or healthcare providers. This is particularly important for seniors managing multiple prescriptions.\n\n*   **AI Voice Assistants Can Help Reduce Social Isolation:** Loneliness and social isolation are major concerns for older adults. AI voice assistants can provide companionship, facilitate communication with family and friends, and offer access to social activities and support groups, helping to combat these issues.\n\n*   **AI Voice Assistants are Becoming More Proactive in Detecting Health Issues:** Future AI voice assistants are expected to go beyond simple commands and proactively monitor seniors' health. By analyzing voice patterns, sleep habits, and activity levels, they can detect early signs of health problems like cognitive decline, depression, or respiratory issues, and alert caregivers or medical professionals.\n\n*   **AI Voice Assistants are Integrating with Smart Home Technology for Enhanced Safety:** The integration of AI voice assistants with smart home devices is creating safer living environments for the elderly. They can control lighting, temperature, and appliances, as well as detect falls, gas leaks, or other emergencies, and automatically call for help.\n\n*   **AI Voice Assistants are Addressing Accessibility and Usability Challenges:** Developers are actively working on making AI voice assistants more accessible and user-friendly for older adults with varying levels of technical skills. This includes simplifying voice commands, providing visual aids, and offering personalized support to ensure that seniors can easily adopt and benefit from this technology.", pydantic=None, json_dict=None, agent='Research Specialist', output_format=<OutputFormat.RAW: 'raw'>), TaskOutput(description='Write a 100-word blog post summary about The Future of AI Voice Assistants for the Elderly using the facts from the research.', name=None, expected_output='A blog post summary', summary='Write a 100-word blog post summary about The Future of...', raw='**The Future is Now: How AI Voice Assistants are Revolutionizing Elderly Care**\n\nAI voice assistants are poised to transform elderly care, offering solutions to critical challenges faced by seniors. Studies show they boost medication adherence through reminders and easy access to healthcare information. Crucially, they combat social isolation by facilitating communication and providing companionship.\n\nLooking ahead, AI will proactively detect health issues by analyzing voice a ...
